# %%
from elasticity_module import output_as_pickle
import cfe

# %%
output_as_pickle("data/ghana/Expenditures.csv", "data/ghana/Household_Characteristics.csv", "pickled_data/ghana.pickle")

# %%
output_as_pickle("data/niger/Expenditures.csv", "data/niger/Household_Characteristics.csv", "pickled_data/niger.pickle")

# %%
output_as_pickle("data/nigeria/Nigeria LSMS - Expenditures.csv", "data/nigeria/Nigeria LSMS - HH Characteristics.csv", "pickled_data/nigeria.pickle")

# %%
output_as_pickle("data/senegal/Copy of Senegal - Food Expenditures.csv", "data/senegal/Copy of Senegal - Household Characteristics.csv", "pickled_data/senegal.pickle")

# %%
output_as_pickle("data/togo/Copy of Togo 2018 - Food Expenditures.csv", "data/togo/Copy of Togo 2018 - HH Characteristics.csv", "pickled_data/togo.pickle")

# %%
output_as_pickle("data/burkina_faso/Copy of Burkina Faso - Food Expenditures.csv", "data/burkina_faso/Copy of Burkina Faso - Household Characteristics.csv", 
                 "pickled_data/burkina_faso.pickle")

# %%
result.Ar
# Out:
# t        m        j
# 2016-17  Ashanti  Agushie Seed    0.019302
#                   Apple           0.014942
#                   Avocado        -0.217872
#                   Banana         -0.094266
#                   Beef            0.213505
#                                     ...
#          Western  Water           0.152955
#                   Watermelon     -0.062149
#                   White Oats     -0.091165
#                   Yam            -0.351651
#                   Yoghurt        -0.076933
# Name: Ar, Length: 840, dtype: float64

# %%
result.get_beta().sort_values()
# Out:
# j
# Cocoyam            0.552203
# Beer               0.727662
# Chicken (live)     0.734651
# Pawpaw             0.798624
# Salt               0.805371
#                      ...
# Instant Noodle     2.121119
# Juice              2.160818
# Biscuit            2.201968
# Chewing Gum        2.208452
# Oil (vegetable)    2.263329
# Name: beta, Length: 84, dtype: float64

# %%
result.graph_beta()

# %%
result.gamma
# Out:
# k             Females 00-00  Females 01-04  Females 05-09  Females 10-14  \
# j
# Agushie Seed      -0.044762       0.041567       0.074391       0.062820
# Apple             -0.117457      -0.083966      -0.213926      -0.118047
# Avocado           -0.098618       0.014417      -0.163240      -0.048094
# Banana            -0.132097      -0.060040      -0.032614      -0.028999
# Beef              -0.025509      -0.133835      -0.128134      -0.080486
# ...                     ...            ...            ...            ...
# Water             -0.132690      -0.131964      -0.101236      -0.039361
# Watermelon        -0.284611      -0.112292      -0.113394      -0.121745
# White Oats         0.049832      -0.045094      -0.114336      -0.131749
# Yam                0.021336      -0.087182      -0.013689       0.027638
# Yoghurt            0.090630      -0.052453      -0.023780      -0.060772
#
# k             Females 15-19  Females 20-29  Females 30-49  Females 50-59  \
# j
# ...

# %%
result.to_pickle('my_estimates.pickle')
