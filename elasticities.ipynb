# %%
# !pip install CFEDemands
import cfe

# %%
result_burkinafaso = cfe.regression.read_pickle("pickled_data/burkina_faso.pickle")
result_ghana =  cfe.regression.read_pickle("pickled_data/ghana.pickle")
result_niger = cfe.regression.read_pickle("pickled_data/niger.pickle")
result_nigeria = cfe.regression.read_pickle("pickled_data/nigeria.pickle")
result_senegal = cfe.regression.read_pickle("pickled_data/senegal.pickle")
result_togo = cfe.regression.read_pickle("pickled_data/togo.pickle")

# %% [markdown]
# Elasticity of Burkina Faso

# %%
result_burkinafaso.get_beta().sort_values()
result_burkinafaso.graph_beta()

# %% [markdown]
# Elasticity of Ghana

# %%
result_ghana.get_beta().sort_values()
result_ghana.graph_beta()

# %% [markdown]
# Elasticity of Niger

# %%
result_niger.get_beta().sort_values()
result_niger.graph_beta()

# %% [markdown]
# Elasticity of Nigeria

# %%
result_nigeria.get_beta().sort_values()
result_nigeria.graph_beta()

# %% [markdown]
# Elasticity of Senegal

# %%
result_senegal.get_beta().sort_values()
result_senegal.graph_beta()

# %% [markdown]
# Elasticity of Togo

# %%
result_togo.get_beta().sort_values()
result_togo.graph_beta()
